# %% [markdown]
# ## Chapter 7 - Exercise 4:  Visualization with Seaborn - Diamond

# %% [markdown]
# _Nghịch lý Simpson hay hiệu ứng Yule–Simpson, là một nghịch lý trong xác suất và thống kê, trong đó một xu hướng xuất hiện trong dữ liệu sẽ bị đảo ngược khi được phân tích dưới góc nhìn khác._
# - https://eropi.com/news/tieu-chuan-danh-gia-kim-cuong/
# -  https://www.youtube.com/watch?v=hDQ0T6-i1rk&t=183s
# #### Có phải kim cương càng lớn thì có giá càng cao ?

# %% [markdown]
# #### Cho dữ liệu diamonds có sẵn trong seaborn library. Hãy thực hiện các yêu cầu sau, để phát hiện nghịch lý Simpson khi phân tích giá kim cương bằng các công cụ trực quan hóa dữ liệu:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
# Câu 1: Đọc dữ liệu diamonds và lưu vào biến diamonds
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
# tiêu chuẩn từ thấp đến cao (4C: cut, color, clarity, carat)
cut_cats = ['Fair', 'Good', 'Very Good', 'Premium', 'Ideal']
color_cats = ['J', 'I', 'H', 'G', 'F', 'E', 'D']
clarity_cats = ['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

# %%
# Câu 2: Vẽ biểu đồ bar so sánh giá của kim cương theo color, cut và clarity
# Bạn nhận xét gì qua biểu đồ này
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
sns.barplot(x='color', y='price', data=diamonds, ax=ax1, order=color_cats)
sns.barplot(x='cut', y='price', data=diamonds, ax=ax2, order=cut_cats)
sns.barplot(x='clarity', y='price', data=diamonds, ax=ax3, order=clarity_cats)
fig.suptitle('Price Decreasing with Increasing Quality?',fontsize=15)
plt.show()

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %%
# Câu 3: Bây giờ, hãy thử Phân tích chi tiết hơn 
# thuộc tính 'carat' theo 'color' và 'clarity' qua biểu đồ catplot - bar plot
# Bạn nhận xét gì qua biểu đồ này
plt.rcParams["axes.labelsize"] = 15
sns.catplot(x='color', y='carat', col='clarity', col_wrap=4, data=diamonds,
kind='bar', order=color_cats,
col_order=clarity_cats)
plt.show()

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %% [markdown]
# => Kim cương kích thước nhỏ thì chất lượng thường cao

# %%
# Câu 4: Vẽ biểu đồ bar so sánh 'carat' của kim cương theo color, cut và clarity
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14,4))
sns.barplot(x='color', y='carat', data=diamonds, ax=ax1, order=color_cats)
sns.barplot(x='cut', y='carat', data=diamonds, ax=ax2, order=cut_cats)
sns.barplot(x='clarity', y='carat', data=diamonds, ax=ax3, order=clarity_cats)
fig.suptitle('Diamond size and quality')
plt.show()

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %%
# Câu 5: Hãy chia carat ra làm 5 khoảng giá trị, 
# tạo cột diamonds['carat_category'] chứa khoảng giá trị tương ứng 
# https://pbpython.com/pandas-qcut-cut.html
# Hướng dẫn: sử dụng hàm pd.qcut
# diamonds['carat_category'] = pd.qcut(diamonds.carat, 5)
diamonds['carat_category'] = pd.qcut(diamonds.carat, 5)
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#   carat_category
# 0  (0.199, 0.35]
# 1  (0.199, 0.35]
# 2  (0.199, 0.35]
# 3  (0.199, 0.35]
# 4  (0.199, 0.35]

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>carat</th>
#       <th>cut</th>
#       <th>color</th>
#       <th>clarity</th>
#       <th>depth</th>
#       <th>table</th>
#       <th>price</th>
#       <th>x</th>
#       <th>y</th>
#       <th>z</th>
#       <th>carat_category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.23</td>
#       <td>Ideal</td>
#       <td>E</td>
#       <td>SI2</td>
#       <td>61.5</td>
#       <td>55.0</td>
#       <td>326</td>
#       <td>3.95</td>
#       <td>3.98</td>
#       <td>2.43</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.21</td>
#       <td>Premium</td>
#       <td>E</td>
#       <td>SI1</td>
#       <td>59.8</td>
#       <td>61.0</td>
#       <td>326</td>
#       <td>3.89</td>
#       <td>3.84</td>
#       <td>2.31</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.23</td>
#       <td>Good</td>
#       <td>E</td>
#       <td>VS1</td>
#       <td>56.9</td>
#       <td>65.0</td>
#       <td>327</td>
#       <td>4.05</td>
#       <td>4.07</td>
#       <td>2.31</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.29</td>
#       <td>Premium</td>
#       <td>I</td>
#       <td>VS2</td>
#       <td>62.4</td>
#       <td>58.0</td>
#       <td>334</td>
#       <td>4.20</td>
#       <td>4.23</td>
#       <td>2.63</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.31</td>
#       <td>Good</td>
#       <td>J</td>
#       <td>SI2</td>
#       <td>63.3</td>
#       <td>58.0</td>
#       <td>335</td>
#       <td>4.34</td>
#       <td>4.35</td>
#       <td>2.75</td>
#       <td>(0.199, 0.35]</td>
#     </tr>
#   </tbody>
# </table>
# </details>

# %%
# Câu 6: Phân tích chi tiết hơn thuộc tính 'price' theo  'clarity','carat_category',
# 'color' qua biểu đồ catplot - point plot
g = sns.catplot(x='clarity', y='price', data=diamonds,
hue='carat_category', col='color',
col_wrap=3, kind='point')
g.fig.suptitle('Diamond price by size, color and clarity',
y=1.02, size=20)
plt.show()

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %%
# Câu 7: Vẽ barplot
sns.barplot(x='carat_category', y='price', data=diamonds)
plt.show()

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %%
# Kết luận:carat càng lớn thì giá càng cao!
