# %% [markdown]
# ## Chapter 6 - Exercise 5: WordClouds

# %% [markdown]
# ### Part 1:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
# Tạo dataframe df từ file dữ liệu Youtube04-Eminem.csv, in vài dòng dữ liệu đầu của df
df = pd.read_csv("data/Youtube04-Eminem.csv", encoding ="latin-1") 
df.head()
# Out:
#                             COMMENT_ID         AUTHOR  \
# 0    z12rwfnyyrbsefonb232i5ehdxzkjzjs2    Lisa Wellas
# 1  z130wpnwwnyuetxcn23xf5k5ynmkdpjrj04   jason graham
# 2    z13vsfqirtavjvu0t22ezrgzyorwxhpf3     Ajkal Khan
# 3  z12wjzc4eprnvja4304cgbbizuved35wxcs  Dakota Taylor
# 4    z13xjfr42z3uxdz2223gx5rrzs3dt5hna    Jihad Naser
#
#                          DATE  \
# 0                         NaN
# 1  2015-05-29T02:26:10.652000
# 2                         NaN
# 3  2015-05-29T02:13:07.810000
# 4                         NaN
#
#                                              CONTENT  CLASS
# 0        +447935454150 lovely girl talk to me xxxï»¿      1
# 1  I always end up coming back to this song<br />ï»¿      0
# 2  my sister just received over 6,500 new <a rel=...      1
# 3                                            Coolï»¿      0
# 4                   Hello I&#39;am from Palastineï»¿      1

# %%
df['CONTENT'].head()
# Out:
# 0          +447935454150 lovely girl talk to me xxxï»¿
# 1    I always end up coming back to this song<br />ï»¿
# 2    my sister just received over 6,500 new <a rel=...
# 3                                              Coolï»¿
# 4                     Hello I&#39;am from Palastineï»¿
# Name: CONTENT, dtype: object

# %%
# Chuẩn bị STOPWORD
stopwords = set(STOPWORDS) 
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
comment_words = ' '.join(df['CONTENT'])
comment_words
# Out:
# '+447935454150 lovely girl talk to me xxxï»¿ I always end up coming back to this song<br />ï»¿ my sister just received over 6,500 new <a rel="nofollow" class="ot-hashtag" href="https://plus.google.com/s/%23active">#active</a> youtube views Right now. The only thing she used was pimpmyviews. comï»¿ Coolï»¿ Hello I&#39;am from Palastineï»¿ Wow this video almost has a billion views! Didn&#39;t know it was so popular ï»¿ Go check out my rapping video called Four Wheels please â\x9d¤ï¸\x8fï»¿ Almost 1 billionï»¿ Aslamu Lykum... From Pakistanï»¿ Eminem is idol for very people in EspaÃ±a and Mexico or Latinoamericaï»¿ Help me get 50 subs please ï»¿ i love song :)ï»¿ Alright ladies, if you like this song, then check out John Rage.Â\xa0 He&#39;s a smoking hot rapper coming into the game.Â\xa0 He&#39;s not better than Eminem lyrically, but he&#39;s hotter. Hear some of his songs on my channel.ï»¿ The perfect example of abuse from husbands and the thing is I&#39;m a feminist so I definitely agree with this song and well...if I see this someone&#39;s going to die! Just sayin.ï»¿ The boyfriend was Charlie from the TV show LOST ï»¿ <a href="https://www.facebook.com/groups/100877300245414/">https://www.facebook.com/groups/100877300245414/</a>ï»¿ Take a look at this video on YouTube:ï»¿ Check out our Channel for nice Beats!!ï»¿ Rihanna and Eminem together are unstoppable.ï»¿ Check out this playlist on YouTube:ï»¿ This song is about Rape and Cheating Â\xa0 Â\xa0Â\xa0<br /><br /><br /><br /><br /><br /><br /><br /><br /><br />Basically.....ï»¿ like pleaseï»¿ I love this song, can&#39;t believe it was 5 years ago, it doesn&#39;t get old thoughï»¿ OMG that looks just like a piece of the mirror of harry potter and the deathly hallows.<br />Either that house. (sirius black)ï»¿ I shared my first song &quot;I Want You&quot;, and I hope you&#39;ll like it. Take a listen!â\x9c\x8cï¸\x8fð\x9f\x98\x8a <a href="https://youtu.be/-YfUY4gKr1c">https://youtu.be/-YfUY4gKr1c</a>ï»¿ Come and check out my music!Im spamming on loads of videos but its just to try and get my music across to new peopleï»¿ Check out this playlist on YouTube:ï»¿ HUH HYUCK HYUCK IM SPECIAL WHO&#39;S WATCHING THIS IN 2015 IM FROM AUSTRALIA OR SOMETHING GIVE ME ATTENTION PLEASE IM JUST A RAPPER WITH A DREAM IM GONNA SHARE THIS ON GOOGLE PLUS BECAUSE IM SO COOL.ï»¿ You exactly who u want to be,watching your favourite rappers on tvï»¿ Rihanna is absolutely gorgeous in this video.ï»¿ Check out this video on YouTube:<br /><br />Love this song... It&#39;s all good will never go back that but I&#39;ll always remember the passion but never want to go back to being dysfunctional insanity....... Goal is to live happy not live insane. ï»¿ Don&#39;t love someone soo much, love the way u lie..ï»¿ one of the BEST SONGS in music historyï»¿ Check out this playlist on YouTube:ï»¿ Check out this video on YouTube:ï»¿ Check out this video on YouTube:ï»¿ No-I hate The Way U LIe!!ï»¿ Fuck Eminem. Bieber is the best &lt;3ï»¿ Check out this playlist on YouTube:chcfcvzfzfbvzdrï»¿ Check out this playlist on YouTube: ï»¿ Im gonna share a little ryhme canibus blows eminem away a quadrillion times especially about the categories of intelligent things in his mind. That he learned and rapped about and forgot before eminem spit his first ryme.luv ya linz 4eï»¿ Check out this video on YouTube:ï»¿ Check out this video on YouTube<br /><br /><br />ï»¿ CHECK OUT THE NEW REMIX !!!<br />CLICK CLICK !!ï»¿ Check out this playlist on YouTube:ï»¿ I personally have never been in a abusive relationship. I probably never will. I don&#39;t hit women. Mom has my dad used to hit my mom before he left. I can relate I&#39;m writing about one at the moment subscribe to hear it. EVERY fan counts.ï»¿ Loveð\x9f\x98\x98â\x9d¤ð\x9f\x92\x96ï»¿ Haha, I can&#39;t believe how many kids listen to Eminem.  You kids know that he does drugs and ends high in jail. I wonder why he never ended OD. ï»¿ plese subscribe to meï»¿ Check out this video on YouT ...

# %% [markdown]
# ## Câu 1: Vẽ WordClouds cho dữ liệu này (có loại bỏ stop word)

# %%
wc = WordCloud(stopwords=stopwords)
wc.generate(comment_words)

plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %% [markdown]
# ### Part 2:

# %%
# Sử dụng vietnamese stop word từ : https://github.com/stopwords/vietnamese-stopwords => 
# tạo thành set các stop words
data = np.loadtxt(r'data\vietnamese-stopwords.txt', delimiter='\n', encoding='utf-8', dtype='str')
stopwords = set(data)
type(stopwords)
# Out:
# set

# %%
# Đọc file ngon_tu_quang_cao.txt => đưa nội dung vào biến text
text = ''
with open(r'data\ngon_tu_quang_cao.txt', 'r', encoding='utf-8') as f:
    text = f.read()

# %%
# Bổ sung thêm một số từ không quan trọng vào stopwords
list_of_words = ['mái nhà','cây cầu']
stopwords.update(list_of_words)

# %% [markdown]
# ## Câu 2: Vẽ wordclouds

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>

# %%
from PIL import Image

# %%
wc1 = WordCloud(stopwords=stopwords)
wc1.generate(text)

# Chọn hình làm wc_mask phù hợp
wc_mask = np.array(Image.open('data/heart.jpg'))
plt.imshow(wc_mask, interpolation='bilinear')
plt.axis('off')
plt.show()

plt.imshow(wc1, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Câu 3:  Vẽ wordclouds với wc_mask

# %% [markdown]
# <details>
#   <summary style='color:#FD6504; font-size:14px'>Nhấn vào đây để xem kết quả!</summary>
# <img src="data:image/png;base64,...
# ">
# </details>
